# %%
from google_play_scraper import app
import pandas as pd
import numpy as np
from google_play_scraper import Sort, reviews

# %%
# Link aplikasi yang ingin diambil ulasannya
app_link = 'com.vidio.android'

# Pengaturan bahasa dan negara
lang = 'id'
country = 'id'

# Pengaturan untuk mengambil ulasan yang paling relevan
sort_option = Sort.MOST_RELEVANT

# Jumlah ulasan yang ingin diambil
reviews_count = 100

# Filter untuk mengambil semua skor atau rating bintang 1 sampai 5
filter_score = None

# Mengambil ulasan dari Google Play
result, continuation_token = reviews(
    app_link,
    lang=lang,
    country=country,
    sort=sort_option,
    count=reviews_count,
    filter_score_with=filter_score
)

import pandas as pd
import numpy as np

# Membuat DataFrame dari hasil ulasan
result_df = pd.DataFrame(np.array(result), columns=['review'])

# Memisahkan kolom 'review' menjadi kolom-kolom terpisah
result_df = result_df.join(pd.DataFrame(result_df.pop('review').tolist()))

# mengambil kolom content dan score saja
filtered_df = result_df[['content','score','at']]

# %%
result
# Out:
# [{'reviewId': '406cb1f2-eb54-4d84-8d68-c5dbb6d5a94e',
#   'userName': 'Kairo & Arafah Videos',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXAdJPK25GRMkhSCw_pgORp_9DC35lA_gBkKT8ze9KlC_I',
#   'content': 'Sudah aktifkan paket mahal2, tapi masih sering kesulitan nonton live bola nya. Gara2 gk bs diakses, dgn notif perangkat melebihi batas. Padahal sudah bolak balik log out trus refresh di semua perangkat masih tetap gk bs ditonton. Sudah terlalu sering seperti ini',
#   'score': 3,
#   'thumbsUpCount': 70,
#   'reviewCreatedVersion': '6.24.12-5917139a17',
#   'at': datetime.datetime(2024, 3, 7, 20, 56, 47),
#   'replyContent': 'Hai, Kak Kairo. Hindari keluar masuk aplikasi halaman menonton di waktu yang berdekatan.\nKakak bisa lakukan force close aplikasi Vidio, tunggu 5-10 menit, lalu coba buka kembali aplikasi Vidio di perangkat. Apabila masih kendala, bisa sampaikan ke info@vidio.com -EF',
#   'repliedAt': datetime.datetime(2024, 3, 7, 21, 1, 50),
#   'appVersion': '6.24.12-5917139a17'},
#  {'reviewId': 'acf0d164-66d1-41f0-b4c0-73464617c4aa',
#   'userName': 'semut ireng777',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXabA62TsX37MnjA5RcEtHlVOcjKYjpbrnU6CkW3MCU6jg',
#   'content': 'Masalah iklan yang terlalu sering ternyata menjadi masalah serius, padahal saya berlangganan premier platinum. Terus masalah paket langganan apa harus memperpanjang secara otomatis,karena langganan yang bulan kemarin belum habis (H-1) tiba2 terdaftar lagi untuk bulan berikutnya. Padahal rencananya saya sudah mau berhenti berlangganan. Baru ini saya kasih bintang 1, untuk sebuah aplikasi,,,maaf ya semoga bisa jadi perhatian dan perbaikan kedepannya.',
#   'score': 1,
#   'thumbsUpCount': 160,
#   'reviewCreatedVersion': '6.23.6-ca3febf9df',
#   'at': datetime.datetime(2024, 3, 4, 15, 53, 3),
#   'replyContent': 'Hai kak Semut. Mohon maaf atas ketidaknyamanan yang kamu alami. Silakan laporkan issue yang sedang dihadapi melalui email ke info@vidio.com atau send feedback dari aplikasi vidio. Jangan lupa untuk melampirkan screenshot masalahmu untuk membantu kami lebih baik dalam memahaminya. Terima kasih - MRD',
#   'repliedAt': datetime.datetime(2024, 3, 4, 16, 0, 44),
#   'appVersion': '6.23.6-ca3febf9df'},
#  {'reviewId': 'daf827ea-f1a8-4379-b91f-ca7dcbc1be9d',
#   'userName': 'Yulian Rizki',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjU9VVbvOaEZqE5gly_dIeMvSELsyc_DVFOHjGBwlaYoPQ',
#   'content': 'sangat mantap aplikasi ini tapi setelah update, malah error walau kecil, dan hari ini Kamis. 29feb malah muncul tulisan Konten tidak tersedia di negara anda saat mau membuka saluran rtv, dan coba pake hape lain, di browser, bisa terkoneksi ke rtv, dan malah muncul tulisan konten tidak tersedia, padahal VPN diatur bawaan dari hape yg berfungsi saat ini, dan tolong segera perbaiki bug ini, karena menyebabkan saya terhalang gak bisa tengok rtv karena bug tersebut.',
#   'score': 1,
#   'thumbsUpCount': 249,
#   'reviewCreatedVersion': '6.23.6-ca3febf9df',
#   'at': datetime.datetime(2024, 2, 29, 20, 36),
#   'replyContent': 'Hai Kak Yulian, mohon maaf untuk ketidaknyamanan yang dialami. Kamu dapat melaporkan issue yang sedang dihadapi saat ini melalui fitur send feedback https://m.vidio.com/sendfeedback atau email ke tim support kami di info@vidio.com, tim kami akan segera menanganinya -JJ',
#   'repliedAt': datetime.datetime(2024, 3, 2, 1, 22, 37),
#   'appVersion': '6.23.6-ca3febf9df'},
#  {'reviewId': 'b271e8cf-2f02-4e4d-ba9e-b426778480b7',
#   'userName': 'NAZWA Safira',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWvAhm59vucJVSZRmjFyd4iw2go-lzz4eBd8gVq41PkEg',
#   'content': 'aslinya aplikasinya udah oke, dari segi film dan resolusi videonya udah bagus. Tapi tolong dong masih ada bug yang tiba tiba video nya jadi macet and than iklannya tolong kurangi, setidaknya jika tidak bisa potong durasi iklan. Menurutku jika iklan masih seperti itu hanya akan membuang waktu banyak hanya untuk menonton iklan. Saya mengerti jika video durasinya 1 jam tapi tolong iklannya cukup 4x saja mnrt sy sdh cukup. kedepannya sy hrp lbh baik ya.',
#   'score': 3,
#   'thumbsUpCount': 480,
#   'reviewCreatedVersion': '6.20.12-9283f82898',
#   'at': datetime.datetime(2024, 2, 20, 19, 6, 10),
#   'replyContent': 'Hai Kak Nazwa, terima kasih telah menggunakan Vidio ya. Saat ini kami terus berupaya meningkatkan kualitas kami, agar anda bisa mengakses Vidio dengan nyaman. Tonton terus konten-konten menarik dari Vidio, dan jangan lupa ditambah bintangnya ya :). -IG',
#   'repliedAt': datetime.datetime(2024, 2, 20, 20, 25, 58),
#   'appVersion': '6.20.12-9283f82898'},
#  {'reviewId': '5c991071-5a99-4570-aec2-3a75d17bd801',
#   'userName': 'Rama D.K.',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXGjoIcTgc4wxoJbq-U_cEvN8uh8FDK7vMPIrRbmBD0vAH9',
#   'content': 'Aplikasinya sebenarnya oke karena bisa menonton mayoritas stasiun televisi di Indonesia, filmnya juga lumayan lengkap seriesnya bagus. Bisa dibuat nonton di ponsel dan televisi pintar. Minusnya adalah kadang ketika nonton di TV muncul iklan di Vidio tapi ngeloop terus kalau tidak di back, anehnya langganan saya Vidio Platinum yang mestinya bebas iklan. Mungkin ada bug.',
#   'score': 4,
#   'thumbsUpCount': 1186,
#   'reviewCreatedVersion': '6.21.12-c7a9fd13c6',
#   'at': datetime.datetime(2024, 1, 28, 0, 9, 32),
#   'replyContent': 'Hai Kak, terkait kendala tersebut, silakan kirimkan melalui fitur send feedback https://m.vidio.com/sendfeedback atau email ke info@vidio.com dan kami ingin mengetahui hal ini agar dapat memperbaikinya -BP',
#   'repliedAt': datetime.datetime(2024, 1, 28, 2, 20, 30),
#   'appVersion': '6.21.12-c7a9fd13c6'},
#  {'reviewId': '11d8e929-309a-4764-8cbf-21a8477bcc65',
#   'userName': 'RamDani Akb47',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVjh-OnT90tK-Nv3EZ0KG2SPRlx9YhnyUXNqF85GDzUgQ',
#   'content': 'Kenapa pas update aplikasi malah patah² video streamingnya terkhusus tayangan bola, sudah dicoba di semua resolusi tertinggi sampai yg terendah hasilnya sama saja. Bagi konsumen seperti kami yg telah berlangganan jelas sangat merugikan & Sangat tidak nyaman untuk ditonton, tolong segera diperbaiki.',
#   'score': 2,
#   'thumbsUpCount': 1078,
#   'reviewCreatedVersion': '6.20.12-9283f82898',
#   'at': datetime.datetime(2024, 1, 23, 3, 47, 13),
#   'replyContent': 'Hai Kak Ramdani, Kami mohon maaf atas ketidaknyamanannya. Untuk mengakses tayangan Vidio dipastikan koneksi internet kamu dalam Keadaan stabil ya. Kami sarankan lakukan clear data pada aplikasi Vidio serta celar data/chace melalui smartphone yang kamu gunakan pada menu setting ya. Kemudian kamu coba kembali. -JJ',
#   'repliedAt': datetime.datetime(2024, 1, 23, 3, 55, 23),
#   'appVersion': '6.20.12-9283f82898'},
#  {'reviewId': '11bef854-5019-4204-aff7-91dd41f5f8ca',
#   'userName': 'Safa Mulya Hardiani',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXRgwGChMXB7WnFknKimQj8enr7CbsI6z9OxddHJdllig',
#   'content': 'jujur kalau bisa kasih bintang 0 saya kasih deh, karena ini aplikasi bagus cuma terlalu banyak iklan di setiap video alhasil jadi ngeganggu, malas nonton pakai aplikasi ini karena banyak iklannya. tolong untuk perbaiki, iklan di kurangi, semoga kritik an saya bisa di terima, di pertimbangkan lalu di lakukan ya, karena untuk apa di buka kolom komentar kaya gini kalau tidak untuk di perbaiki, terima kasih maaf jika ada kalimat yang menyinggung dan terlalu kasar',
#   'score': 1,
#   'thumbsUpCount': 325,
#   'reviewCreatedVersion': '6.20.12-9283f82898',
#   'at': datetime.datetime(2024, 2, 15, 0, 35, 34),
#   'replyContent': 'Hai kak Safa. Mohon maaf atas ketidaknyamanan yang dialami. Perihal apa yang dapat kami bantu? Silakan laporkan kendala yang sedang dihadapi melalui send feedback dari aplikasi Vidio atau email ke info@vidio.com ya. Jangan lupa ditambah bintangnya. Enjoy! -AS',
#   'repliedAt': datetime.datetime(2024, 2, 15, 0, 36, 34),
#   'appVersion': '6.20.12-9283f82898'},
#  {'reviewId': '8ad01253-69c6-4e16-bc7d-d1180df1d51a',
#   'userName': 'Bonita Br Siburian',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjW69E1hR0LZEKKqbbYxveqev0tTHKRJGSi9bI4_knVT9g',
#   'content': 'Ini gimana sih masa mau berlangganan gagal eror mulu. Pilih negara minta di update play store nya tapi tetap ga bisa. Makin lama makin ribet nih aplikasi. Plis jgn buat yg ribet dong 😭 padahal saldo gue cukup banget untuk berlangganan tapi tetap aja ga bisa dan eror.',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '6.23.6-ca3febf9df',
#   'at': datetime.datetime(2024, 3, 8, 16, 24, 46),
#   'replyContent': 'Hai, Kak Bonita, sebagai informasi untuk alternatif pembelian Kakak dapat melakukan pembelian melalui website Vidio, atau dapat juga membuka tautan berikut pada PC/laptop https://www.vidio.com/packages#buy atau menghubungi info@vidio.com -EF',
#   'repliedAt': datetime.datetime(2024, 3, 8, 17, 11, 38),
#   'appVersion': '6.23.6-ca3febf9df'},
#  {'reviewId': '02e870de-fb97-4834-9c3d-3c42a274ee78',
#   'userName': 'peremPUAN',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLtQiC6-k_-lvU-MJ5lgbLbqLK0K3xG09fQmM53E3ke1g=mo',
#   'content': 'untuk film berlangganan platinum vidio,banyak yg gk lengkap seperti fil terminator,dan masih ada lagi,dan ada bug pas nonton kadang ada iklan padahal sudah langganan,dan juga pas nonton film kadang frees dan ke ulang padahal jaringan stabil',
#   'score': 2,
#   'thumbsUpCount': 528,
#   'reviewCreatedVersion': '6.20.12-9283f82898',
#   'at': datetime.datetime(2024, 1, 19, 12, 17, 57),
#   'replyContent': 'Hai Sahabat Vidio. Terima kasih telah menggunakan aplikasi Vidio kak, kami akan terus memperbaiki dan meningkatkan layanan kami agar kamu tetap nyaman nonton di Vidio. Jika ada kendala kamu bisa infokan melalui fitur send feedback https://m.vidio.com/sendfeedback atau juga email ke info@vidio.com ya. Jangan lupa ditambahkan bintangnya ya kak. -JJ',
#   'repliedAt': datetime.datetime(2024, 1, 19, 13, 33, 19),
#   'appVersion': '6.20.12-9283f82898'},
#  {'reviewId': 'ac9e4f53-ecf2-487c-b845-98e7c54646c0',
#   'userName': 'Lans Channel',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUuN-nbA39TLVt0pxd2v75u2fzzRUVzEikavewKes1H6nc',
#   'content': 'bagus banget film banyak, enaknya aplikasi indo itu banyak film indo nya, cuma saya mau kasih saran, bisa tambahkan audio yg bahasa Indonesia? misal Spongebob klo versi inggris kurang lucu, enakan yg bahasa Indonesia audionya itu aja sih',
#   'score': 5,
#   'thumbsUpCount': 404,
#   'reviewCreatedVersion': '6.20.12-9283f82898',
#   'at': datetime.datetime(2024, 1, 14, 8, 44, 19),
#   'replyContent': 'Hai kak, terima kasih bintang penuh dan saran yang diberikan, kami akan sampaikan kepada tim terkait. Karena saran dan masukan yang diberikan sangat berarti untuk kami dalam upaya meningkatkan kepuasan pelayanan pelanggan setia seperti kakak. Selamat menonton! -MA\n',
#   'repliedAt': datetime.datetime(2024, 1, 14, 9, 9, 16),
#   'appVersion': '6.20.12-9283f82898'},
#  {'reviewId': 'fee7e0f1-374e-411a-91c1-f3ea89cc225d',
#   'userName': 'Ali Misnan',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVNFIOW6EVjQoE2vwg_-pdYv9vPyqzin4j1xBOuigymIw',
#   'content': 'Aplikasih luar biasa, pertama beli paket di smart tv vidio platinum total 42 rb an ada potongan voucer 10 rb tapi waktu pembayaran potongannya ga ada, otomatis pembayaran tetap 42 rb sia sia pakai voucer, dan yang kedua paling sebel sudah beli platinum liat vidio nonton expres ga bisa anjir suruh bayar lagi 5rb padahal sudah ada paketan platinum, sumpah ketika abis masa platinum bulan depan auto uninstal gw, kalau bisa nyantumin gambar gw upload sekalian buktinya',
#   'score': 1,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '6.23.6-ca3febf9df',
#   'at': datetime.datetime(2024, 3, 2, 21, 36, 11),
#   'replyContent': 'Hai kak Ali, Mohon maaf atas kendalanya. Bantu kami untuk menyelidiki masalah pembayaranmu melalui email ke info@vidio.com atau https://m.vidio.com/sendfeedback send feedback dari aplikasi vidio. jangan lupa untuk melampirkan screenshots masalahmu untuk membantu kami lebih baik dalam memahaminya. -MA\n',
#   'repliedAt': datetime.datetime(2024, 3, 2, 22, 5, 35),
#   'appVersion': '6.23.6-ca3febf9df'},
#  {'reviewId': '5e4e0daf-a16c-4128-8e5a-4c68145c65ea',
#   'userName': 'Fatima Arfa',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLAFd9GMwoM_Iczsavez48bDyK56YeE0M1g4dV1f-Ub=mo',
#   'content': 'Kak ini knp ya kok dr kemarin apk nya GK bisa bisa buat nonton film tv.jd ke ganggu kan nonton filmnya.. muter-muter trus trus kluar tulisan video ini tidak menanggapi..tolong secepatnya diperbaiki kak',
#   'score': 3,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '6.23.6-ca3febf9df',
#   'at': datetime.datetime(2024, 3, 5, 11, 53, 54),
#   'replyContent': 'Hai Kak Fatima Arfa, perihal apa yang dapat kami bantu ? Jika ada kendala kamu bisa infokan melalui fitur send feedback https://m.vidio.com/sendfeedback atau juga email ke info@vidio.com ya. -MIS',
#   'repliedAt': datetime.datetime(2024, 3, 5, 12, 4, 20),
#   'appVersion': '6.23.6-ca3febf9df'},
#  {'reviewId': 'f9804fa7-dc45-439f-8654-7cdf42d90637',
#   'userName': 'Ridwan Maureksa',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJY2DimhJevsXxyifpzVtkIqgGGMJc8EBXRtL4WJ5Tn=mo',
#   'content': 'setelah update, udah bayar paket diamond tapi ga bisa nonton priemer league, tiba² aplikasi keluar sendiri . pas hapus data baru bisa nonton, tapi paketan ilang (harus paketin lagi) . keren sih bikin rugi orang . 👍🏻',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '6.23.6-ca3febf9df',
#   'at': datetime.datetime(2024, 3, 4, 0, 33, 11),
#   'replyContent': 'Hai kak. kami akan bantu pengecekan untuk kendalanya ya, silahkan kirimkan feedback dari aplikasi Vidio kamu atau email tim support kami di info@vidio.com. Kamu juga bisa akses link berikut https://m.vidio.com/sendfeedback. Terima kasih.-AA\n',
#   'repliedAt': datetime.datetime(2024, 3, 4, 2, 23),
#   'appVersion': '6.23.6-ca3febf9df'},
#  {'reviewId': '2c75f214-bc65-495c-8024-93dfd8a7b9cd',
#   'userName': 'Aditya Ojes',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUzspHhXfCwP_q7XDmXdeEGaPKENvSTY4eXcnpgi9mLDak',
#   'content': 'Untuk Penyediaan berbagai konten sebetulnya nya sangat baik, tetapi kenapa selalu terjadi eror terhadap media atau video yang lagi di tonton. Harapan nya supaya secepatnya di koreksi dan di perbaiki karena sudah dua hari tetap seperti itu....',
#   'score': 3,
#   'thumbsUpCount': 57,
#   'reviewCreatedVersion': '6.22.7-747926fec4',
#   'at': datetime.datetime(2024, 2, 24, 17, 46, 29),
#   'replyContent': 'Hai kak Aditya. Mohon maaf atas ketidaknyamanan yang kamu alami. Silakan laporkan permasalahan detail yang sedang dihadapi melalui email ke info@vidio.com atau send feedback dari aplikasi vidio. Jangan lupa untuk melampirkan screenshot masalahmu untuk membantu kami lebih baik dalam memahaminya - AMC',
#   'repliedAt': datetime.datetime(2024, 2, 24, 17, 52, 5),
#   'appVersion': '6.22.7-747926fec4'},
#  {'reviewId': 'daff99ce-7c32-4940-abf0-2449652c817c',
#   'userName': 'Dams Salafiyyah',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVQTrxjegtjzJ9SizWStMdl2W7VlMp1aTGQG-aNbXGqRg',
#   'content': 'Update review. Sangat memuaskan, ternyata mungkin dulu saya salah beli paket, kalau untuk pc harusnya beli paket untuk semua perangkat. Terimakasih untuk vidio dan tim, semoga sukses selalu menjadi hiburan no 1 di indonesia. Semoga channel sportnya semakin kumplit.',
#   'score': 5,
#   'thumbsUpCount': 71,
#   'reviewCreatedVersion': '6.20.12-9283f82898',
#   'at': datetime.datetime(2024, 1, 30, 1, 15, 50),
#   'replyContent': 'Hai kak Dams, terima kasih 5 bintangnya. Feedback kamu sangat berguna bagi kemajuan Vidio. Kami akan terus memperbaiki layanan kami, agar kamu selalu nyaman dan puas nonton di Vidio. jika ada kendala kamu bisa infokan melalui fitur send feedback https://m.vidio.com/sendfeedback atau juga email ke info@vidio.com ya. selamat menonton. -JJ',
#   'repliedAt': datetime.datetime(2024, 1, 30, 1, 45, 4),
#   'appVersion': '6.20.12-9283f82898'},
#  {'reviewId': '227da32e-f0d7-47d6-8c15-ced089d1e28f',
#   'userName': 'Ayu Dimy Liani',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVQKzKJ9hYkkheIp-ryWw30yjZ_WzM6k2RDcx_1lINMyNs',
#   'content': 'Ini vidio kok jadi gini ya sekarang, kalo streaming pake paket data seluler loading terus padahal sinyal bagus, buat apk lain pun nggak ada kendala Tolong jangan kebanyakan muatannya, sayang banget apk udah bagus cuma gara-gara event" gak terlalu perlu, jadi ngaruh ke kualitas streamingnya Tolong banget ini diperbaiki',
#   'score': 3,
#   'thumbsUpCount': 72,
#   'reviewCreatedVersion': '6.20.12-9283f82898',
#   'at': datetime.datetime(2024, 1, 21, 20, 58, 46),
#   'replyContent': 'Hai Kak Ayu, Kami mohon maaf atas ketidaknyamanannya. Untuk mengakses tayangan Vidio dipastikan koneksi internet kamu dalam Keadaan stabil ya. Kami sarankan lakukan clear data pada aplikasi Vidio serta celar data/chace melalui smartphone yang kamu gunakan pada menu setting ya. Kemudian kamu coba kembali. -JJ',
#   'repliedAt': datetime.datetime(2024, 1, 21, 21, 5, 47),
#   'appVersion': '6.20.12-9283f82898'},
#  {'reviewId': 'a4657e50-1c34-496a-b6e0-b9ae2f4d17aa',
#   'userName': 'Lukman Pryoto',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocI7gXEZzimz3v3EAPYuJXCtg36lZqGdXmRrtNzzMu0J=mo',
#   'content': 'Sudah hampir 2 bulan ini video nya khusus olahraga bola patah2,padahal sebelumnya tidak seperti itu,koneksi udah stabil,sudah diclear chace juga malah udah di uninstal dan di instal tetap juga tidak pengaruh, ini sangat merugikan konsumen yang sudah berlangganan, padahal saya sudah berlangganan sangat lama, tolong kasi solusinya',
#   'score': 1,
#   'thumbsUpCount': 31,
#   'reviewCreatedVersion': '6.21.12-c7a9fd13c6',
#   'at': datetime.datetime(2024, 1, 27, 21, 28, 45),
#   'replyContent': 'Hai kak Lukman, mohon maaf atas kendalanya, kami sarankan untuk mencoba menggunakan koneksi lain ya kak. Jika masih mengalami kendala yang sama bisa hubungi ke email berikut ya info@vidio.com. Terima kasih -MR',
#   'repliedAt': datetime.datetime(2024, 1, 27, 22, 23, 54),
#   'appVersion': '6.21.12-c7a9fd13c6'},
#  {'reviewId': 'b445457d-03fc-4229-a09e-810e6d110b63',
#   'userName': 'Miftahul Zanah',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXXp5cIkcuf7SJO3uR6U0E_pi3Ee1HQNJd1iajXXoT5qLk',
#   'content': 'Aplikasi sampah... Mau berlangganan ribet banget, mau beli harus verifikasi, penulisan sandi udah bener tapi tetep terdeteksi nya salah, gimana sihh',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '6.24.12-5917139a17',
#   'at': datetime.datetime(2024, 3, 9, 15, 6, 36),
#   'replyContent': 'Hai kak Miftahul. Mohon maaf atas ketidaknyamanan yang kamu alami. Silakan laporkan issue yang sedang dihadapi melalui email ke info@vidio.com atau send feedback dari aplikasi vidio. Jangan lupa untuk melampirkan screenshot masalahmu untuk membantu kami lebih baik dalam memahaminya. Terima kasih - AMC',
#   'repliedAt': datetime.datetime(2024, 3, 9, 16, 40, 57),
#   'appVersion': '6.24.12-5917139a17'},
#  {'reviewId': '3323dd02-75d2-4661-a1e1-ead59891320a',
#   'userName': 'Dwi Nurcahyo',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXrecK2buhbUbfqtjhfoqALFL06MBB3wpVKs73mX6e1jKY',
#   'content': 'Kecewa sama pelayanan vidio. Mau nonton bola pun ngelag kek patah-patah gitu. Mana asik. Nanya cs pun jawabannya template banget. Mau refund tapi gak bisa. Payah. Aplikasi streaming butut!',
#   'score': 1,
#   'thumbsUpCount': 6,
#   'reviewCreatedVersion': '6.22.7-747926fec4',
#   'at': datetime.datetime(2024, 2, 26, 0, 52, 25),
#   'replyContent': 'Hai kak Dwi. Mohon maaf atas ketidaknyamanan yang kamu alami. Silakan laporkan issue yang sedang dihadapi melalui email ke info@vidio.com atau send feedback dari aplikasi vidio. Jangan lupa untuk melampirkan screenshot masalahmu untuk membantu kami lebih baik dalam memahaminya. -CN',
#   'repliedAt': datetime.datetime(2024, 2, 26, 4, 0, 40),
#   'appVersion': '6.22.7-747926fec4'},
#  {'reviewId': 'c284abcf-be73-472d-bde6-26d8752c67ff',
#   'userName': 'Noveria Ria',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWvoNPf6nXnXpfok9ZuQaSLu7_Pb1uACJU53BfeK_60cXU',
#   'content': 'Aplikasi nya sudah Bagus tapi masih ada bug,ketika saya sedang menonton tiba tiba suka terulang dari awal filmnya ,terus kalau sudah pertengahan film saya menonton tiba tiba suka keluar dari aplikasi nya',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '6.23.6-ca3febf9df',
#   'at': datetime.datetime(2024, 2, 29, 7, 15, 25),
#   'replyContent': 'Hai Kak, terkait kendala tersebut, silakan kirimkan melalui fitur send feedback https://m.vidio.com/sendfeedback atau email ke info@vidio.com dan kami ingin mengetahui hal ini agar dapat memperbaikinya. -BP',
#   'repliedAt': datetime.datetime(2024, 2, 29, 9, 34, 18),
#   'appVersion': '6.23.6-ca3febf9df'},
#  {'reviewId': '687e6db2-aa08-473f-9f21-f45475542a20',
#   'userName': 'Anggi Permana',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJCzcEc5X3bNPnbrv2lij1cudno-dP5hrUw9MthHs6E=mo',
#   'content': 'Gila sih iklannya ga ada obat co , dari satu vidio lebih dari 5 kali iklannya , mana ga bisa d skip lagi iklannya , mana lama lagi iklanya , iklannya itu lagi itu lagi , waktu iklannya 30 detik , dalam satu vidio ada 7 iklan , 30 detik di kali 7 , 30x7=210 =3menit 30detik , itu satu vidio , kalo 10 vidio 3,5menit kali 10 =setengah jam nonton iklan itu mulu , mana ngeleg2 vidionya ,hadeuhhhh good job',
#   'score': 3,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '6.23.6-ca3febf9df',
#   'at': datetime.datetime(2024, 2, 24, 0, 39, 54),
#   'replyContent': 'Hai Kak. terima kasih atas reviewnya. Yuk berlangganan paket premier kami agar terbebas iklan saat menyaksikan tayangan Vidio, kamu juga bisa loh menikmati semua konten premier jika sudah berlangganan premier diamond ataupun platinum. Jika ingin menyaksikan EPL harus berlangganan Diamond ya.-AA',
#   'repliedAt': datetime.datetime(2024, 2, 24, 3, 30, 33),
#   'appVersion': '6.23.6-ca3febf9df'},
#  {'reviewId': '3a86b1f1-e06c-443c-a1fe-ae66f79f4057',
#   'userName': 'zella anggita',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKmqyDlYBjy3O-ys9Nmdh7pIl3El7-lDnC7ucRqJFxR=mo',
#   'content': 'Sudah membeli paket platinum, saldo ovo sudah terpotong, ada bukti email masuk juga mengenai pembelian paket platinum yang berhasil, tapi di akun vidio-nya masih belum berlangganan. Sudah lapor ke pusat bantuan vidio tidak ada tanggapan.',
#   'score': 1,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '6.23.6-ca3febf9df',
#   'at': datetime.datetime(2024, 3, 5, 22, 48, 15),
#   'replyContent': 'Hai kak Zella. Mohon maaf atas ketidaknyamanan yang kamu alami. Silakan laporkan issue yang sedang dihadapi melalui email ke info@vidio.com atau send feedback dari aplikasi vidio. Jangan lupa untuk melampirkan screenshot masalahmu untuk membantu kami lebih baik dalam memahaminya. -BP',
#   'repliedAt': datetime.datetime(2024, 3, 5, 23, 34, 24),
#   'appVersion': '6.23.6-ca3febf9df'},
#  {'reviewId': '9a7de84d-4f3f-4435-8056-5fc7f53de1d5',
#   'userName': 'Hardana Satriani',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUIoslYOY4xfiu0i4r2oo9uT_V7rAAg0EuFxudRAjfn2w',
#   'content': 'Bagus, mudah mudahan bisa berkembang fitur dan bertambah jumlah Chanel TV Nasional-nya. Satu hal yang saya keluhkan adalah terkadang muncul iklan yang tidak semestinya muncul karena sudah berlangganan, mudah mudahan menjadi perhatian serius dan bisa segera diperbaiki. Terima kasih.',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '6.23.6-ca3febf9df',
#   'at': datetime.datetime(2024, 3, 3, 19, 50),
#   'replyContent': 'Hai Ka Hardana! Terima kasih atas penilaian terbaiknya. Kami selalu berusaha meningkatkan pelayanan kami untuk para pelanggan setia. Jika ada kendala kamu bisa informasikan melalui fitur send feedback https://m.vidio.com/sendfeedback atau juga email ke info@vidio.com yaa. Terima kasih. - AMC',
#   'repliedAt': datetime.datetime(2024, 3, 3, 20, 13, 19),
#   'appVersion': '6.23.6-ca3febf9df'},
#  {'reviewId': '08d275ad-7ed3-4d4b-84a0-9250e5bf4b9d',
#   'userName': 'RP',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXCxNRmGoqUoetWzcWKasITny3wg5jUTeN4MpH_UDeB9Q',
#   'content': 'Aplikasi bagus tpi beli paket kek gk ada gunanya pindah divice ke laptop bisa, mau balik ke hp seharian gk mau tulisan gk bisa masuk padahal di laptop udh di keluarin, mau login di laptop lgi sama aja udh gk bisa, tulisannya "tidak bisa masuk" kan kocak asu asu sia sia beli paket',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '6.23.6-ca3febf9df',
#   'at': datetime.datetime(2024, 3, 3, 22, 53, 36),
#   'replyContent': 'Hai Kak, terkait kendala tersebut, silakan kirimkan melalui fitur send feedback https://m.vidio.com/sendfeedback atau email ke info@vidio.com dan kami ingin mengetahui hal ini agar dapat memperbaikinya. -BP\n\n',
#   'repliedAt': datetime.datetime(2024, 3, 3, 23, 46, 20),
#   'appVersion': '6.23.6-ca3febf9df'},
#  {'reviewId': 'baf50293-53a1-4099-9338-07f8b488b3d5',
#   'userName': 'Adi Yusuf',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVxfq-ctIZ6Kc0MXsJ2VC7BBgF7x0QoOc9UgvrEOXo2z_A',
#   'content': 'Aplikasi udah oke tapi suka tiba" muter" dan nunggu jeda beberapa detik dulu. Jadi kurang asik liat streaming bola',
#   'score': 3,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '6.23.6-ca3febf9df',
#   'at': datetime.datetime(2024, 3, 3, 22, 42, 35),
#   'replyContent': 'Hai Kak, terkait kendala tersebut, silakan kirimkan melalui fitur send feedback https://m.vidio.com/sendfeedback atau email ke info@vidio.com dan kami ingin mengetahui hal ini agar dapat memperbaikinya. -BP',
#   'repliedAt': datetime.datetime(2024, 3, 3, 23, 45, 52),
#   'appVersion': '6.23.6-ca3febf9df'},
#  {'reviewId': '1cf5dd29-e4f7-4928-a727-e583356893df',
#   'userName': 'Efwan Hasby',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjV_WzZwopW_hdgsZb2SsUQsEUD1lFFnKhqPsYg76339b4s',
#   'content': 'Sedikit saran untuk film, drama dsb. Mohon sertakan nilai imdb. Itu bakal jadi rujukan selain sinopsis. Juga fitur pencarian bisa lebih dikembangkan lagi, misal saya pengen nonton film yg diperanin si A, atau film yg disutradarai si B. Thanks',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '6.23.6-ca3febf9df',
#   'at': datetime.datetime(2024, 2, 27, 1, 35, 15),
#   'replyContent': 'Hai kak Efwan. Kami selalu berusaha memberikan yang terbaik untuk pelanggan setia kami. Jika kamu ada kendala terkait dengan vidio silakan send feedback dari aplikasi atau email ke info@vidio.com ya. Jangan lupa ditambah bintangnya ya. Enjoy! -CN',
#   'repliedAt': datetime.datetime(2024, 2, 27, 2, 23, 12),
#   'appVersion': '6.23.6-ca3febf9df'},
#  {'reviewId': '8ade9c13-7f29-4e6d-83e4-3eb03ac45c69',
#   'userName': 'Fieta Kusuma',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKjVXVBxVp56NX_IuKb-WVjQlbyoyk_J7XCH1HKoXn2=mo',
#   'content': 'Hello pekerja" aplikasi Video xan sudah saya jelaskan bahwa di aplikasi Video banyak tontonan yg harus langganan Video Platinum baru bisa dilihat, jadi tidak perlu discrenshoot, lebih bagus hapus saja aturan langganan Video Platinum, hanya buang" pulsa & uang, 🤨',
#   'score': 1,
#   'thumbsUpCount': 31,
#   'reviewCreatedVersion': '6.23.6-ca3febf9df',
#   'at': datetime.datetime(2024, 3, 8, 13, 31, 32),
#   'replyContent': 'Hai kak Fieta. ada banyak tayangan yang bisa kamu saksikan secara gratis di Vidio ya. Namun jika ingin bisa menyaksikan semua tayangan Premier (berlambang mahkota) dan terbebas dari iklan, kami sarankan kamu untuk mengaktifkan paket Diamond atau Platinum terlebih dahulu. -EY\n',
#   'repliedAt': datetime.datetime(2024, 3, 8, 13, 35, 35),
#   'appVersion': '6.23.6-ca3febf9df'},
#  {'reviewId': 'fbfd02b4-36c6-484c-b100-3cc9060bd6da',
#   'userName': 'Kelvin',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLfhACu37ce2G8uUVHVUy2X7gCAGsy_sKZ0S3mia5o=mo',
#   'content': 'Jangan pernah download nih apk apalagai berlangganan saya jamin menyesal!!!kemarin saya menyampaikan keluhan video tidak dapat diputar dan belum ada jawaban sampai langganan saya akan habis.customer ngasih embel" bales bintang 1 cuma buat bikin kalian tertarik doang selebihnya setelah berlangganan gak akan peduli sama permasalahan kalian.SAYA INGATKAN!!!',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '6.23.6-ca3febf9df',
#   'at': datetime.datetime(2024, 3, 5, 11, 2, 37),
#   'replyContent': 'Hai kak Kelvin. Jika saat ini terdapat kendala saat akses Vidio silakan lakukan \'\'Send Feedback\'\' atau "Kirim Laporan" melalui aplikasi Vidio atau bisa email kami di info@vidio.com ya guna dibantu solusikan atas kendalanya. Jangan lupa ditambah bintangnya ya :) -MIS',
#   'repliedAt': datetime.datetime(2024, 3, 5, 12, 3, 26),
#   'appVersion': '6.23.6-ca3febf9df'},
#  {'reviewId': 'c672c68d-f6a2-475e-a7d0-3bb8fbac184d',
#   'userName': 'Ahmad Sanjaya eboy1 Ahmad Sanjaya eboy1',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLj-DYrIefqYwOptqB0TZQEcbQtzIeg7EOQc-Zl7zBj=mo',
#   'content': 'Tidak dapat memberhentikan berlangganan.dan uang di akun wallet langsung di potong padahal sudah tidak menggunakan aplikasi ya.sagat membuat kecewa.saya mau berhenti berlangganan malah ditolak sistem ya sendiri',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '6.23.6-ca3febf9df',
#   'at': datetime.datetime(2024, 2, 29, 20, 51, 1),
#   'replyContent': 'Hai Kak , perihal apa yang dapat kami bantu ? Jika ada kendala kamu bisa infokan melalui fitur send feedback https://m.vidio.com/sendfeedback atau juga email ke info@vidio.com ya. -MIS',
#   'repliedAt': datetime.datetime(2024, 2, 29, 21, 5, 8),
#   'appVersion': '6.23.6-ca3febf9df'},
#  {'reviewId': 'c5a5068b-1037-4d0d-bbfa-4d30c45bfdd6',
#   'userName': 'Yogha Bogi Pratama',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUXLB_82qjQ1-9AnWon94OdByf770SApUGZBngsH8Iz50Y',
#   'content': 'setelah update terakhir tidak terdaftar sebagai paket platinum, padahal saya masih berlangganan malah diteruskan untuk memilih paket berlangganan, padahal durasi paket saya masih lama',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '6.23.6-ca3febf9df',
#   'at': datetime.datetime(2024, 3, 2, 10, 31, 48),
#   'replyContent': 'Hai kak Yogha. Mohon maaf atas ketidaknyamanan yang kamu alami. Silakan laporkan issue yang sedang dihadapi melalui email ke info@vidio.com atau send feedback dari aplikasi vidio. Jangan lupa untuk melampirkan screenshot masalahmu untuk membantu kami lebih baik dalam memahaminya. Terimakasih - MRD',
#   'repliedAt': datetime.datetime(2024, 3, 2, 10, 40, 16),
#   'appVersion': '6.23.6-ca3febf9df'},
#  {'reviewId': 'f68fae68-1d22-4a3f-9169-4868db3f13ee',
#   'userName': 'Diovany Oktarini',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVULrNQ180bM7ndmn10lKzi8Yrg9ouB7wvYem4nvN98Hw',
#   'content': 'Sejauh ini apknya bagus,tapi tolong dong admin kurangi iklannya dikit🙏🏻 menurutku iklannya terlalu banyak+lama 😌kalo bisa iklan pendek2 aja biar enak;) selebihnya udh oke 👌',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '6.23.6-ca3febf9df',
#   'at': datetime.datetime(2024, 2, 26, 17, 52, 20),
#   'replyContent': 'Hai kak Oktarini, terima kasih atas reviewnya. Yuk berlangganan paket diamond/platinum agar terbebas iklan saat menyaksikan tayangan Vidio, kamu juga bisa loh menikmati semua konten premier jika sudah berlangganan diamond/platinum. -MR',
#   'repliedAt': datetime.datetime(2024, 2, 26, 18, 7, 11),
#   'appVersion': '6.23.6-ca3febf9df'},
#  {'reviewId': '00528a6c-96a2-4650-9277-8b4ba69a0256',
#   'userName': 'Ashari Alfahreza',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIJnW3RlTNjs_A1yp8gKLxdpXYr0Ia8mWMV8OG49-HQ=mo',
#   'content': 'Dalam proses pembayaran kenapa ada peringatan."pastikan telah memilih negara yang benar di akun play anda".sehingga tidak bisa melanjutakan pembayaran.solusi nya bagaimana ?trimakasih.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '6.23.6-ca3febf9df',
#   'at': datetime.datetime(2024, 3, 7, 20, 34, 4),
#   'replyContent': 'Hai Kak Ashari. Sebagai informasi untuk alternatif pembelian Kakak dapat melakukan pembelian melalui website Vidio, atau dapat juga membuka tautan berikut pada PC/laptop https://www.vidio.com/packages#buy -EF',
#   'repliedAt': datetime.datetime(2024, 3, 7, 20, 37, 52),
#   'appVersion': '6.23.6-ca3febf9df'},
#  {'reviewId': 'c6b96c59-8e3d-4b9f-bd59-f6b5d919a3f7',
#   'userName': 'suherdi yansyah',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjV0v1GMBSOVdX3xox8-Rx02uAQFCwQjD52TwIJZ7InckQ',
#   'content': 'Bintang 1 dulu,aneh sama streamingnya selalu dikit"loading,giliran iklan lancar jaya,buka YouTube 1080 lancar,nanti kalo udah bener baru bintang 5',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '6.23.6-ca3febf9df',
#   'at': datetime.datetime(2024, 3, 2, 20, 22, 32),
#   'replyContent': 'Hai kak Suherdi. Mohon maaf atas ketidaknyamanan yang dialami. Silakan laporkan kendala yang sedang dihadapi melalui send feedback dari aplikasi Vidio atau email ke info@vidio.com ya. Jangan lupa ditambah bintangnya. Happy watching! - AMC',
#   'repliedAt': datetime.datetime(2024, 3, 2, 22, 3, 42),
#   'appVersion': '6.23.6-ca3febf9df'},
#  {'reviewId': 'aac6d458-5e37-4535-8d82-1f7ee773417b',
#   'userName': 'Raus Xcvb',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVH_uHNLQEMYzLsGtSyyArXopfk8BM8PyCUPnpOlzVY8A',
#   'content': 'Parah gak nyaman lagi nonton film iklan nya ganggu,gak bisa di skip lagi,mohon di perbaiki,supaya gak ada iklan,saya kasih bintang 2 dlu,kalo iklannya udah gak ganggu saat nonton,saya kasih bintang 5',
#   'score': 2,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '6.21.12-c7a9fd13c6',
#   'at': datetime.datetime(2024, 2, 23, 20, 26, 15),
#   'replyContent': 'Hai, Kak Raus. Kami informasikan juga apabila Anda menonton channel TV nasional yang tersedia di Vidio, memang tidak akan bebas dari iklan ya. Atau bisa konfirmasikan E-mail Vidio Kakak yang sudah berlangganan ke E-mail info@vidio.com -EF.',
#   'repliedAt': datetime.datetime(2024, 2, 23, 20, 34, 33),
#   'appVersion': '6.21.12-c7a9fd13c6'},
#  {'reviewId': '1a63c878-8ea4-48de-b219-9cd4a565d4a2',
#   'userName': 'Miftahur Rohman',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIXZUyRBGcZzCHZGc_TVQ2wJ8ZqPoSpIm__3GkpAKFr=mo',
#   'content': 'Burik burik,makin di update bukannya bagus malah banyak kendala seperti muter muter padahal sinyal bagus,patah patah tolonglah untuk developer nya kalau mau update itu yang teliti saya kasih bintang dua dulu nanti kalau ada perkembangan saya tambahin lagi 🙏🏻🙏🏻🙏🏻',
#   'score': 2,
#   'thumbsUpCount': 20,
#   'reviewCreatedVersion': '6.21.12-c7a9fd13c6',
#   'at': datetime.datetime(2024, 1, 29, 21, 27, 12),
#   'replyContent': 'Hai kak Miftahur, mohon maaf atas ketidaknyamannya. Silahkan untuk mencoba refresh kembali dan clear data/cache melalui menu setting di aplikasi Vidio yang digunakan ya. Jika masih mengalami kendala serupa, silahkan kirimkan feedback dari aplikasi Vidio kamu atau email tim support kami di info@vidio.com. -MA\n',
#   'repliedAt': datetime.datetime(2024, 1, 29, 21, 47, 30),
#   'appVersion': '6.21.12-c7a9fd13c6'},
#  {'reviewId': '18ed2f6f-84af-40fc-9a1f-ebde9aa80079',
#   'userName': 'Defri Setyawan',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXjevJjmiadkierJwwHtMPaFxiudKgpcLdpL49dlVuBdoo',
#   'content': 'Bagus . Tapi paketannya kurang menarik. Mana update pembayaran otomatis lagi. Semua perangkat harga 2x.',
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '6.23.6-ca3febf9df',
#   'at': datetime.datetime(2024, 3, 3, 19, 21, 15),
#   'replyContent': 'Hai Kak Defri, terkait kendalanya silakan lakukan \'\'Send Feedback\'\' atau "Kirim Laporan" melalui aplikasi Vidio atau bisa email kami di info@vidio.com ya guna dibantu solusikan atas kendalanya. Jangan lupa ditambah bintangnya ya :) -IG',
#   'repliedAt': datetime.datetime(2024, 3, 3, 20, 33, 18),
#   'appVersion': '6.23.6-ca3febf9df'},
#  {'reviewId': '3ae385f0-6080-45bf-9c9b-affb03b3d917',
#   'userName': 'Prabu raden Siliwangi',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIWBuokL7PJR06zNOqG4NrPsmXot9jRWlcB1XvHhlRi=mo',
#   'content': 'Vidio sekarang ga bisa liat siaran ulang bola parah dulu mah bisa Dulu enak suka sama vidio sekarang jadi males karna mau liat siaran ulang aja ga bisa parah padahal bukan live streaming cuma liat siaran ulang aja susah harus premium dulu parah . Ga liat barito sama persib',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '6.23.6-ca3febf9df',
#   'at': datetime.datetime(2024, 2, 26, 21, 18, 13),
#   'replyContent': 'Hai kak Prabu. Mohon maaf atas ketidaknyamanannya, silakan laporkan kendalanya melalui email ke info@vidio.com atau send feedback dari aplikasi Vidio. Tim kami akan segera membantu kakak. -MA\n',
#   'repliedAt': datetime.datetime(2024, 2, 26, 21, 36, 46),
#   'appVersion': '6.23.6-ca3febf9df'},
#  {'reviewId': '65c3f033-a5d1-432c-9132-e5f1b98953db',
#   'userName': 'Keken Bay',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUCHVWUFeHuPKToVMmbLetX86_NLSLtuqJDcdYFOYPj4i4',
#   'content': 'di update malah gajelas , udah bayar menonton siaran bola malah patah patah , udah make wifi dan data seluler tetep aja patah patah , ga ada penyelesaian nya payah',
#   'score': 1,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': '6.23.6-ca3febf9df',
#   'at': datetime.datetime(2024, 2, 23, 0, 53, 50),
#   'replyContent': 'Hai kak Keken. Mohon maaf atas ketidaknyamanan yang kamu alami. Silakan laporkan issue yang sedang dihadapi melalui email ke info@vidio.com atau send feedback dari aplikasi vidio. Jangan lupa untuk melampirkan screenshot masalahmu untuk membantu kami lebih baik dalam memahaminya. -CN',
#   'repliedAt': datetime.datetime(2024, 2, 23, 3, 59, 1),
#   'appVersion': '6.23.6-ca3febf9df'},
#  {'reviewId': '01e00fc9-1c11-401d-96de-b24659e66431',
#   'userName': 'MUHAMAD REHADATUL AISYI',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWB8GhgQ8VxdfrHkT8pjPeFs-0ZqJyAKrawS8la2u0zA1c',
#   'content': 'Untuk semuanya bagus. Cocok. Gk da iklan.cuman perpanjang berlanggannya otomatis dan gk bisa di atur nonotomatis. Merugikan pengguna.kebutuhan gk di Aplikasi Vidio doang min. Tolong di perbaiki. Terima kasih',
#   'score': 3,
#   'thumbsUpCount': 140,
#   'reviewCreatedVersion': '6.21.12-c7a9fd13c6',
#   'at': datetime.datetime(2024, 2, 6, 20, 30, 21),
#   'replyContent': "Hai Sahabat Vidio, terkait pelaporannya silakan lakukan ''Send Feedback'' melalui aplikasi Vidio atau bisa email kami di info@vidio.com ya guna dibantu solusikan atas kendalanya. Jangan lupa ditambah bintangnya ya :) -CN",
#   'repliedAt': datetime.datetime(2024, 2, 6, 20, 53, 52),
#   'appVersion': '6.21.12-c7a9fd13c6'},
#  {'reviewId': '42a01706-844e-4abc-b838-3496a54fb280',
#   'userName': 'Adam Nuryaman',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXR3fUtqqEs-IhAwaTJcXasHXG8bRbgCy95S63O_Jgg_Vw',
#   'content': 'Mau beli paket gabisa mulu,muncul error pas beli paket padahal saldo udah cukup malah lebih herman dah nih apk. Diperbaiki jngan mempersulit pengguna apk',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '6.23.6-ca3febf9df',
#   'at': datetime.datetime(2024, 3, 9, 15, 55, 9),
#   'replyContent': 'Hai kak Adam. Mohon maaf atas ketidaknyamanan yang kamu alami. Silakan laporkan issue yang sedang dihadapi melalui email ke info@vidio.com atau send feedback dari aplikasi vidio. Jangan lupa untuk melampirkan screenshot masalahmu untuk membantu kami lebih baik dalam memahaminya. Terima kasih - AMC',
#   'repliedAt': datetime.datetime(2024, 3, 9, 16, 34, 15),
#   'appVersion': '6.23.6-ca3febf9df'},
#  {'reviewId': 'd9389396-c131-41fb-b5ae-42a5846812a3',
#   'userName': '30. Sultan Abid Assegaf',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVGa6i7oMTG5-iCRLB-VfGDd6k5TIGC26H_06_J8KZ-Ag',
#   'content': 'dari live nya sudah bagus, tapi kurang lengkap seperti contoh, saya nonton live nba tapi yg ditayangkan cuman beberapa saja dari pertandingan di hari yg sama',
#   'score': 3,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': '6.23.6-ca3febf9df',
#   'at': datetime.datetime(2024, 2, 23, 10, 30, 11),
#   'replyContent': 'Hai kak Sultan. Terima kasih atas feedbacknya. Sebagai informasi untuk tayangan Livestreaming NBA mengikuti kebijakan dari pemilik program. Kami selalu berusaha memberikan yang terbaik untuk pelanggan setia kami. Jika kamu ada kendala terkait dengan vidio silakan send feedback dari aplikasi atau email ke info@vidio.com ya. Selamat menonton! - TH\n',
#   'repliedAt': datetime.datetime(2024, 2, 23, 10, 37, 13),
#   'appVersion': '6.23.6-ca3febf9df'},
#  {'reviewId': 'c9e3ee71-4d3f-4a9c-94e0-9e453dac1943',
#   'userName': 'Yogi Setiyo',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjU3ubpKTRjtkUWMbSrTL_0vK8CnEjaRIzlHL6q6AOGBnbs',
#   'content': 'Entah kenapa setelah langganan malah gak bisa mutar video,, jaringan bagus.. sampah sekali',
#   'score': 1,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '6.23.6-ca3febf9df',
#   'at': datetime.datetime(2024, 3, 7, 11, 12, 15),
#   'replyContent': 'Hai Ka Yogi! Mohon maaf atas ketidaknyamanan yang kamu alami. Jika ada kendala kamu bisa informasikan melalui fitur send feedback https://m.vidio.com/sendfeedback atau juga email ke info@vidio.com yaa. Terima kasih –ADZ',
#   'repliedAt': datetime.datetime(2024, 3, 7, 13, 9, 51),
#   'appVersion': '6.23.6-ca3febf9df'},
#  {'reviewId': 'a44c0820-d01d-493a-aa60-dd4d91dd9a24',
#   'userName': 'Achex A.K',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIb0PthvivWcCs2GwsWoOnSxBjm-bi5oSffLHfHU6AH=mo',
#   'content': 'Apk makin sini makin aneh, ngbug kadang video gk bisa D klik, pas nnton bola keluar sendiri error, hadeuh pdhal langganan biar nyaman nnton malah bikin naik darah.',
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '6.23.6-ca3febf9df',
#   'at': datetime.datetime(2024, 3, 8, 0, 59, 38),
#   'replyContent': 'Hai kak Achex. Mohon maaf atas ketidaknyamanannya, silakan laporkan kendalanya melalui email ke info@vidio.com atau send feedback dari aplikasi Vidio. Tim kami akan segera membantu kakak. -MA',
#   'repliedAt': datetime.datetime(2024, 3, 8, 1, 21, 6),
#   'appVersion': '6.23.6-ca3febf9df'},
#  {'reviewId': 'f5a6e358-b770-4a35-86f5-fd313adac032',
#   'userName': 'ryo adiputra',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLJLutqeCDLJZgA2UT9yhVEWmD1mCcdstjn4F2gZgtO=mo',
#   'content': 'Kenapa sering error waktu membuka konten2 nya, saya sudah bayar, dan ketika mau melihat pertandingan2 olahraga selalu error',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '6.23.6-ca3febf9df',
#   'at': datetime.datetime(2024, 3, 2, 10, 33, 31),
#   'replyContent': 'Hai kak Ryo. Mohon maaf atas ketidaknyamanan yang kamu alami. Silakan laporkan issue yang sedang dihadapi melalui email ke info@vidio.com atau send feedback dari aplikasi vidio. Jangan lupa untuk melampirkan screenshot masalahmu untuk membantu kami lebih baik dalam memahaminya. Terimakasih - MRD',
#   'repliedAt': datetime.datetime(2024, 3, 2, 10, 40, 40),
#   'appVersion': '6.23.6-ca3febf9df'},
#  {'reviewId': '1d3e4429-6e5f-4fda-b67c-b9b2cc032ca4',
#   'userName': 'Joe Joel',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXkanL3txPYg4WsrEf9PBf_nPRTQAd9Anz_rORKujbNP38',
#   'content': 'Aplikasi cukimay, langganan 1tahun paket diamond pengaturan kwalitas video 1080p harus manual aplikasi sering logout jawaban admin hanya normatif tanpa ada perbaikan aplikasi.',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '6.23.6-ca3febf9df',
#   'at': datetime.datetime(2024, 3, 5, 21, 11, 20),
#   'replyContent': 'Hai Sahabat Vidio. Mohon maaf atas ketidaknyamanan yang kamu alami. Silakan laporkan issue yang sedang dihadapi melalui email ke info@vidio.com atau send feedback dari aplikasi vidio. Jangan lupa untuk melampirkan screenshot masalahmu untuk membantu kami lebih baik dalam memahaminya. -CN',
#   'repliedAt': datetime.datetime(2024, 3, 5, 22, 29, 19),
#   'appVersion': '6.23.6-ca3febf9df'},
#  {'reviewId': '91555ead-e5d8-4479-9110-51f7dd5a7d67',
#   'userName': 'Reza Abdillah',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUOuG8jaoxtKRBxwmnqw5xisMlt4DaFmaKrvb1qN2X7B78',
#   'content': 'Tolong di perbaiki kualitas videonya selalu lag dan patah patah ,padahal sudah berbayar.',
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '6.23.6-ca3febf9df',
#   'at': datetime.datetime(2024, 3, 8, 22, 41, 40),
#   'replyContent': 'Hai Sahabat Vidio. Mohon maaf atas ketidaknyamanan yang dialami, kami sarankan untuk mencoba kembali dengan menggunakan jaringan internet yang lebih stabil ya, silakan clear data pada aplikasi Vidio yang digunakan dan mencoba menurunkan resolusi tayangan tersebut. Apabila masih terkendala silakan hubungi kami di email info@vidio.com - RL\n',
#   'repliedAt': datetime.datetime(2024, 3, 8, 23, 38, 7),
#   'appVersion': '6.23.6-ca3febf9df'},
#  {'reviewId': 'ab4402e2-c245-4e69-9585-b9fce27794fc',
#   'userName': 'Entin Wantini',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocILj-0wJgMnqgJWUgXw_8yOGDv0XxwmjkS-Pc3TGz73=mo',
#   'content': 'Nyusahin pelanggan terlalu banyak ngerubah paket, jadi tambah mahal, mau bayar aja susah apalagi mau nonton, kurang informatif bila ada perubahan paket maupun kebijakan👎👎👎👎👎',
#   'score': 1,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': '6.23.6-ca3febf9df',
#   'at': datetime.datetime(2024, 2, 26, 11, 35, 28),
#   'replyContent': 'Hai kak Entin. Mohon maaf atas ketidaknyamanan yang kamu alami. Silakan laporkan issue yang sedang dihadapi melalui email ke info@vidio.com atau send feedback dari aplikasi vidio. Jangan lupa untuk melampirkan screenshot masalahmu untuk membantu kami lebih baik dalam memahaminya. -TH',
#   'repliedAt': datetime.datetime(2024, 2, 26, 11, 50, 19),
#   'appVersion': '6.23.6-ca3febf9df'},
#  {'reviewId': '1f00fc1d-b0bc-4310-bde5-0ae67c71b86c',
#   'userName': 'muhammad adi nurcahyono',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKfdOtooAtKMaSia2-JYzYX3RSpJZMxq5pBf7uBgLej=mo',
#   'content': 'Semoga keluhan saya terkait streaming bola yang bufering padahal sudah berlangganan paket vidio diamond mobile 1 tahun dan memakai wifi yg stabil bisa segera diperbaiki. Saat ini saya kasih bintang 3 dulu kalau sdh diperbaiki saya kasih ke Bintang 5.',
#   'score': 3,
#   'thumbsUpCount': 11,
#   'reviewCreatedVersion': '6.21.12-c7a9fd13c6',
#   'at': datetime.datetime(2024, 2, 10, 20, 0, 44),
#   'replyContent': 'Haloo Kak!! Terima kasih telah menggunakan Vidio dan mohon maaf atas ketidaknyamanannya. Terkait kendalanya, kakak bisa infokan melalui fitur send feedback https://m.vidio.com/sendfeedback atau bisa melalui email kami ke info@vidio.com yaaa.. Jangan lupa ditambah bintangnya ya. - AMR',
#   'repliedAt': datetime.datetime(2024, 2, 10, 21, 42, 13),
#   'appVersion': '6.21.12-c7a9fd13c6'},
#  {'reviewId': 'c3bafa5d-a9f3-4ed5-82bb-fe1ddf3ff512',
#   'userName': 'Rivad latul',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjX_hmaDDSFP43x1iSTHgqvw2iQjgFvd8yVvr0DkvdnfaQ',
#   'content': 'Sekarang banyak iklan nya, nonton sinetron, drama series , setiap ganti episode baru mulai, pertengahan film, iklan mulu,sesekali mah wajar lah, ini ganti episode , ganti tayangan ,ganti film, pertrngahan film , bahkan perempatan film, aja iklan mulu, banyak banget ,hadeuh',
#   'score': 1,
#   'thumbsUpCount': 1703,
#   'reviewCreatedVersion': '6.19.6-57ca02382d',
#   'at': datetime.datetime(2023, 12, 20, 3, 3, 49),
#   'replyContent': 'Hai Kak Rivad. Agar dapat terbebas dari iklan dan bisa menyaksikan semua konten Premier yang tersedia, yuk berlangganan paket Vidio melalui aplikasi atau website kami terlebih dahulu melalui link https://www.vidio.com/packages#buy -IG\n',
#   'repliedAt': datetime.datetime(2023, 12, 20, 3, 10, 36),
#   'appVersion': '6.19.6-57ca02382d'},
#  {'reviewId': '6012574d-d3d7-4e7a-a0ab-6e15d83101ab',
#   'userName': 'Siti Novi',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocI_-17LyoVEfRNoiRhF7Lzbv7RMpNXvT0-Sq0LV7zYM=mo',
# ...
#   'content': 'Aneh banget, saya nonton anime one piece dari epsd 1.saat udah season 5 langsung ke season 20,terus untuk apa saya membeli premium!?,kembaliin uang saya!!,anime nya juga di tambahin lah,jangan cuman dramanya aja, mending beli premium di apk lain!',
#   'score': 1,
#   'thumbsUpCount': 11,
#   'reviewCreatedVersion': '6.21.12-c7a9fd13c6',
#   'at': datetime.datetime(2024, 2, 2, 20, 31, 44),
#   'replyContent': 'Hai kak Dhika, untuk konten One Piece yang tayang di Vidio sudah disesuaikan dengan kebijakan dari pemilik konten. Kami akan terus mengembangkan dan meningkatkan konten yang tersedia di Vidio agar dapat terus memberikan pengalaman yang baik bagi semua pengguna Vidio. Jangan lupa ditambah bintangnya ya kak. ~JJ',
#   'repliedAt': datetime.datetime(2024, 2, 2, 21, 9, 38),
#   'appVersion': '6.21.12-c7a9fd13c6'},
#  {'reviewId': 'e403a6e3-3e40-4f6f-ac64-b39e7c2edeee',
#   'userName': 'Ramadhan Rabbani',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUkyFGzOfh0u0F_YoCWCT9wCidLaCCdJ-l6-93Gj2sEzsM',
#   'content': 'Beli langganan , berhasil tapi tetap ada iklan, sudah beli lewat googleplay, Pembayaran berhasil tetapi tidak dengan aplikasi vidionya, saya ada bukti transaksinya, ada jadwal nya ada nomor GPA nya .. tapi apa ? laporannya juga slow respon',
#   'score': 1,
#   'thumbsUpCount': 9,
#   'reviewCreatedVersion': '6.21.12-c7a9fd13c6',
#   'at': datetime.datetime(2024, 2, 5, 5, 53, 3),
#   'replyContent': 'Hai kak Rabbani, mohon maaf atas ketidaknyamannya. Kami akan bantu pengecekan untuk kendalanya ya, silahkan kirimkan feedback dari aplikasi Vidio kamu atau email tim support kami di info@vidio.com. -MR\n',
#   'repliedAt': datetime.datetime(2024, 2, 5, 6, 46, 42),
#   'appVersion': '6.21.12-c7a9fd13c6'},
#  {'reviewId': 'db800962-05c6-4175-8535-2ee37897e1f8',
#   'userName': 'Rahmat Pratama',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUgCGth8fFTsCh-l3bu7GrI_LEkSO9zYp9k0NEpOvp-5Q',
#   'content': 'Dear Developer, Pliss sediakan pengaturan daftar device login... Biar mudah kontrol akses bila terjadi limit layar... Masa saya yang punya akun kena limit layar cuma gara gara lupa pernah login dimana...',
#   'score': 1,
#   'thumbsUpCount': 6,
#   'reviewCreatedVersion': '6.20.12-9283f82898',
#   'at': datetime.datetime(2024, 1, 19, 0, 45),
#   'replyContent': 'Hai Kak Rahmat, terima kasih telah menggunakan Vidio ya. Saat ini kami terus berupaya meningkatkan kualitas kami, agar anda bisa mengakses Vidio dengan nyaman. Tonton terus konten-konten menarik dari Vidio, dan jangan lupa ditambah bintangnya ya :). -IG',
#   'repliedAt': datetime.datetime(2024, 1, 19, 0, 55, 43),
#   'appVersion': '6.20.12-9283f82898'},
#  {'reviewId': 'ec494562-b1a2-43ae-8cf5-2225fe87a869',
#   'userName': 'Ajwa Fitriani',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocISc1xvYL5Ski6YFvSYhix96lQ1rRM8EjqngHbhQH8h=mo',
#   'content': 'menurutku ini udah bagus tapi kok bisa jadi bug dan gk lancar vidio nya dari segi kualitas videonya udah bagus banget. harap diperbaiki',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '6.22.7-747926fec4',
#   'at': datetime.datetime(2024, 2, 26, 13, 27, 3),
#   'replyContent': 'Hai kak Ajwa. Mohon maaf atas ketidaknyamanan yang kamu alami. Silakan laporkan issue yang sedang dihadapi melalui email ke info@vidio.com atau send feedback dari aplikasi vidio. Jangan lupa untuk melampirkan screenshot masalahmu untuk membantu kami lebih baik dalam memahaminya. -TH',
#   'repliedAt': datetime.datetime(2024, 2, 26, 15, 0, 46),
#   'appVersion': '6.22.7-747926fec4'},
#  {'reviewId': '1dc847a6-d346-450c-a0b3-12bd52d0c358',
#   'userName': 'Nabilah Haya AS',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXhfzGF1iX9FF0bkfK4hYjl5vV823lccbHELfqzFRCOr9k',
#   'content': 'Sebelum-sebelumnya aplikasi nontonnya bagus kenapa akhir" ini mau nonton muter terus padahal pakai wifi dan paketan data dan saya juga sudah ke warkop ya ttp saya muter terus buffering',
#   'score': 2,
#   'thumbsUpCount': 9,
#   'reviewCreatedVersion': '6.21.12-c7a9fd13c6',
#   'at': datetime.datetime(2024, 2, 5, 11, 8),
#   'replyContent': "Hai Kak Nabilah, terkait kendalanya silakan lakukan ''Send Feedback'' melalui aplikasi Vidio atau bisa email kami di info@vidio.com ya guna dibantu solusikan atas kendalanya. Jangan lupa ditambah bintangnya ya :) -IG",
#   'repliedAt': datetime.datetime(2024, 2, 5, 11, 27, 7),
#   'appVersion': '6.21.12-c7a9fd13c6'},
#  {'reviewId': '6dbb5ffb-1914-42c6-bb4a-eafd4c9b0f07',
#   'userName': 'Lisa Andryn',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLm2rW_gOzGWuDi8fqFippf7dG2N7wXHurtfrlUu7ze=mo',
#   'content': 'Baru download, tapi video loading terus. Ga kebuka. Padahal jaringan satu WiFi dengan hape suami.. di suami bisa buka Vidio. Tapi di aku ngga.. udah hapus dan instal ulang ga juga bisa...',
#   'score': 2,
#   'thumbsUpCount': 8,
#   'reviewCreatedVersion': '6.21.12-c7a9fd13c6',
#   'at': datetime.datetime(2024, 1, 29, 13, 5, 15),
#   'replyContent': 'Hai Sahabat Vidio. Mohon maaf atas ketidaknyamanan yang kamu alami. Silakan laporkan issue yang sedang dihadapi melalui email ke info@vidio.com atau send feedback dari aplikasi vidio. Jangan lupa untuk melampirkan screenshot masalahmu untuk membantu kami lebih baik dalam memahaminya. -CT\n\n',
#   'repliedAt': datetime.datetime(2024, 1, 29, 14, 8, 10),
#   'appVersion': '6.21.12-c7a9fd13c6'},
#  {'reviewId': 'f2f23664-4140-4e9c-994f-eeb5ca42d5d0',
#   'userName': 'Ferdhy rafsanjani',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWGIhJqoZoQSu1OeBff1aD4AfbwEhGerhNvzrWpijShUw8',
#   'content': 'Sdh langganan platinum berbayar tapi iklan msh muncul, jadi buat apa bayar kalo iklan msh nongol selama 6 detik, Dan satu lagi tolong thumbnail film2 nya diperbesar lgi, thumbnail kecil2 gak menarik samsek',
#   'score': 4,
#   'thumbsUpCount': 8,
#   'reviewCreatedVersion': '6.21.12-c7a9fd13c6',
#   'at': datetime.datetime(2024, 1, 30, 22, 1, 23),
#   'replyContent': 'Hai kak Ferdhy, mohon maaf ketidaknyamanan yang dialami. Kamu dapat melaporkan issue yang sedang dihadapi saat ini melalui send "Feed Back/Kirim laporan" dari aplikasi Vidio dengan membuka tautan berikut https://m.vidio.com/sendfeedback atau email ke tim support kami di info@vidio.com, tim kami akan segera menanganinya -MA\n',
#   'repliedAt': datetime.datetime(2024, 1, 30, 22, 52, 55),
#   'appVersion': '6.21.12-c7a9fd13c6'},
#  {'reviewId': '9c7e28d5-751d-44a7-be34-26d986690ed1',
#   'userName': 'AZIZAH DWI',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVtvp7bfVO7ZMdij_cBt5nHu5MhZOaz3ET5ZzppeZEpmXg',
#   'content': 'Maaf ya sebelumnya saya download vidio ini tidak bisa diputar film nya malah muncul warna yg dominan hitam abu", mngkin bnyak yg blng mslh jaringan tapi jaringan saya lancar" dibuat youtube, tiktok, ig aman tpi ko buat mutar film di vidio ko ga bisa. Mohon perbaikannya yaa',
#   'score': 1,
#   'thumbsUpCount': 5,
#   'reviewCreatedVersion': '6.20.12-9283f82898',
#   'at': datetime.datetime(2024, 1, 17, 20, 10, 51),
#   'replyContent': 'Hai Sahabat Vidio, perihal apa yang dapat kami bantu? Silahkan kirimkan feedback dari aplikasi Vidio dengan membuka tautan berikut https://m.vidio.com/sendfeedback atau email tim support kami ya di info@vidio.com untuk pertanyaan, saran atau masukan seputar Vidio. Terimakasih.-AA\n',
#   'repliedAt': datetime.datetime(2024, 1, 17, 20, 37, 50),
#   'appVersion': '6.20.12-9283f82898'},
#  {'reviewId': '03ab3f94-4ce7-4414-ab3d-eefbc00e1279',
#   'userName': 'Andi Sugandi',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXOG9ztxmHH86PjPxA37iuuFi7Adcb86P7CsJ0dMmI2cA',
#   'content': 'buat pihak vidio tolong lah setiap ada film luar itu bahasanya bisa di ubah kaya Netflix apalagi kartu saya lebih suka nonton film kartu yang berbahasa Indonesia mangkanya saya jarang sekali langganan vidio cuma karna ada bola saja sih semoga pihak vidio mendengar keluhan saya dan satu lagi kok film serial India nya hilang sih',
#   'score': 1,
#   'thumbsUpCount': 4,
#   'reviewCreatedVersion': '6.21.12-c7a9fd13c6',
#   'at': datetime.datetime(2024, 2, 8, 14, 4, 53),
#   'replyContent': 'Hai Sahabat Vidio. Mohon maaf atas ketidaknyamanan yang kamu alami. Silakan laporkan issue yang sedang dihadapi melalui email ke info@vidio.com atau send feedback dari aplikasi vidio. Jangan lupa untuk melampirkan screenshot masalahmu untuk membantu kami lebih baik dalam memahaminya. -CN',
#   'repliedAt': datetime.datetime(2024, 2, 8, 15, 41, 18),
#   'appVersion': '6.21.12-c7a9fd13c6'},
#  {'reviewId': '33f5902a-9b27-4266-835c-12a997496600',
#   'userName': 'Ainani Tajrian',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVwai0E07UVI7iKZw-TyPAvL7281Oz2yCTmLrzi5v1r7xw',
#   'content': 'Sangat kecewa sekarang kalo mau donwload filmnya harus berbayar padahal aku mau mendonwload beberapa film aja tapi harus berbayar untuk dapat semua fiturnya',
#   'score': 5,
#   'thumbsUpCount': 11,
#   'reviewCreatedVersion': '6.21.12-c7a9fd13c6',
#   'at': datetime.datetime(2024, 2, 2, 11, 17, 26),
#   'replyContent': 'Hi kak! Mohon maaf atas ketidaknyamanannya. Untuk saat ini hanya pengguna yang memilki langganan premier yang dapat menggunakan fitur download ya,yuk berlangganan paket premier platinum , Kamu juga bisa menikmati semua konten premier jika sudah berlangganan premier platinum melalui vidio.com/packages. - RL\n',
#   'repliedAt': datetime.datetime(2024, 2, 2, 13, 10, 1),
#   'appVersion': '6.21.12-c7a9fd13c6'},
#  {'reviewId': 'd257244d-8dfe-4546-9746-a5530cc037d1',
#   'userName': 'Soviana ayu trisnanda',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVHtQnINV7q49cgBhyYORCPI-vTjaEhbf0pbAK1ayTvKVs',
#   'content': 'Sering banget eror, percuma langganan eror" Nggak jelas terus. Chat complain cuma di suruh yg restart lah apa lah ttp aja gak bisa.... Eror nya di film yg lagi di tonton lagi.',
#   'score': 1,
#   'thumbsUpCount': 7,
#   'reviewCreatedVersion': '6.21.12-c7a9fd13c6',
#   'at': datetime.datetime(2024, 1, 26, 18, 42, 6),
#   'replyContent': 'Hai kak Soviana. Mohon maaf atas ketidaknyamanan yang kamu alami. Silakan laporkan issue yang sedang dihadapi melalui email ke info@vidio.com atau send feedback dari aplikasi vidio. Jangan lupa untuk melampirkan screenshot masalahmu untuk membantu kami lebih baik dalam memahaminya. -TH',
#   'repliedAt': datetime.datetime(2024, 1, 26, 19, 23, 1),
#   'appVersion': '6.21.12-c7a9fd13c6'},
#  {'reviewId': '2444e670-4b4a-4e0e-84f7-c87dda459f6b',
#   'userName': 'Bang Tambunan',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVnowTCrt8vmDVDlnpaGx5-xHaG5ULeno-tbP0rgyEufQ',
#   'content': 'Setelah update, kok ada bug yah, setelah menonton kurang dari 1 menit, keluar sendiri dari apk nya, dan patah" Saat menonton, tolong di perbaiki lagi',
#   'score': 1,
#   'thumbsUpCount': 8,
#   'reviewCreatedVersion': '6.21.12-c7a9fd13c6',
#   'at': datetime.datetime(2024, 1, 26, 10, 27, 35),
#   'replyContent': 'Hai Sahabat Vidio, mohon maaf untuk ketidaknyamanan yang dialami. Kamu dapat melaporkan issue yang sedang dihadapi saat ini melalui fitur send feedback https://m.vidio.com/sendfeedback atau email ke tim support kami di info@vidio.com, tim kami akan segera menanganinya -JJ',
#   'repliedAt': datetime.datetime(2024, 1, 26, 12, 34, 46),
#   'appVersion': '6.21.12-c7a9fd13c6'},
#  {'reviewId': 'ae75e3f9-05d6-4b62-9615-c2fdbc204b33',
#   'userName': 'Andika Rafly',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVTGqHwqSKJ-zChDb-Fo20o9BQ82jTk7C4NjOPvkmrCQg',
#   'content': 'Saya sudah bayar paket platinum mahasiswa via dana, tetapi sampai saat ini saya masih belum bisa mengakses paket tersebut, saya merasa sangat dirugikan jika uang saya keluar hanya untuk hal yang sia sia. Tolong segera diperbaiki masalahnya.',
#   'score': 3,
#   'thumbsUpCount': 6,
#   'reviewCreatedVersion': '6.21.12-c7a9fd13c6',
#   'at': datetime.datetime(2024, 2, 1, 19, 49, 57),
#   'replyContent': 'Hai kak. kami akan bantu pengecekan untuk kendalanya ya, silahkan kirimkan feedback dari aplikasi Vidio kamu atau email tim support kami di info@vidio.com. Kamu juga bisa akses link berikut https://m.vidio.com/sendfeedback. Terima kasih.-AA\n',
#   'repliedAt': datetime.datetime(2024, 2, 1, 21, 51, 40),
#   'appVersion': '6.21.12-c7a9fd13c6'},
#  {'reviewId': 'f4cefe0a-ed31-484b-ac9b-27cca0f85f30',
#   'userName': 'Akrom Fariz',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXyMmY9GIQejORTSxB83CfzBRwaO4E1kRI_EHwhjjrPXyU',
#   'content': 'Suara jalan gambar enggak, hp redmi noe 10 pro , gamungkin ga suport, koneksi lancar, jangan sampe kalah saing sama layanan streaming lain gara2 jelek bgini',
#   'score': 1,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '6.20.10-c0def59c2c',
#   'at': datetime.datetime(2024, 1, 12, 14, 30, 30),
#   'replyContent': 'Hai Kak Akrom, mohon maaf ketidaknyamanan yang dialami. Kamu dapat melaporkan issue yang sedang dihadapi saat ini melalui send "Feed Back/Kirim laporan" dari aplikasi Vidio dengan membuka tautan berikut https://m.vidio.com/sendfeedback atau email ke tim support kami di info@vidio.com, tim kami akan segera menanganinya -EY\n',
#   'repliedAt': datetime.datetime(2024, 1, 12, 14, 34, 41),
#   'appVersion': '6.20.10-c0def59c2c'},
#  {'reviewId': '1a073a7c-84ea-41ed-893e-b56b7cb6c9a0',
#   'userName': 'Alpian Alpian',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJDF2Gd7NKQT8lY_ZvPHV8ZgoNqbRLdK990fgx7sr7_=mo',
#   'content': 'Manimal iklannya dikurangi lah masa mau nonton siaran tv tambah iklan aplikasi lagi sampai dua kali lagi kalo gini mending unduh versi mod tentu gak ada iklan dari yg ori beri iklan gak ngotak',
#   'score': 1,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': '6.20.12-9283f82898',
#   'at': datetime.datetime(2024, 1, 25, 20, 6, 46),
#   'replyContent': 'Hai kak Alpian, ada banyak tayangan yang bisa disaksikan secara gratis. Namun untuk mengakses konten premier, kamu diharuskan untuk berlangganan terlebih dahulu ya. Yuk berlangganan paket Vidio dan nikmati tayangan tanpa iklan. Jangan lupa ditambahkan bintangnya ya kak. -RL\n',
#   'repliedAt': datetime.datetime(2024, 1, 25, 21, 40, 19),
#   'appVersion': '6.20.12-9283f82898'},
#  {'reviewId': '74302061-02b1-44ae-ad64-4fdedd4e373c',
#   'userName': 'Delia Lia',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIfkzRUCDwiP77hPzVhYTaToPKZkGhZnORqOCQbMOsS=mo',
#   'content': 'Kenapa ya sekarang aplikasi vidio jadi susah banget kalau mau di buka,suka gak ada gambar cuman hitap layar nya... Tolong dong di perbaiki,padahal awal² aku download baik² aja',
#   'score': 1,
#   'thumbsUpCount': 6,
#   'reviewCreatedVersion': '6.21.12-c7a9fd13c6',
#   'at': datetime.datetime(2024, 1, 26, 15, 38, 34),
#   'replyContent': 'Hai kak Delia, mohon maaf ketidaknyamanan yang dialami. Kamu dapat melaporkan issue yang sedang dihadapi saat ini melalui send "Feed Back/Kirim laporan" dari aplikasi Vidio dengan membuka tautan berikut https://m.vidio.com/sendfeedback atau email ke tim support kami di info@vidio.com, tim kami akan segera menanganinya -EY\n',
#   'repliedAt': datetime.datetime(2024, 1, 26, 15, 56, 57),
#   'appVersion': '6.21.12-c7a9fd13c6'},
#  {'reviewId': '5e2eb1df-2741-4319-938e-e0dc6dacbca6',
#   'userName': 'ludi hertanto',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVh2x8ON6u82mTVxOG-ShIkUPwfIjp_Xc0UwoFXyk7bHB4',
#   'content': 'Minimal tv nasionalnya dilengkapin dong, mnc grup supaya digandeng. Klo lengkap kan gak usah pake aplikasi lain lain lagi enak, sebagai ganti dari tayangan semua channel tv digital',
#   'score': 1,
#   'thumbsUpCount': 7,
#   'reviewCreatedVersion': '6.20.12-9283f82898',
#   'at': datetime.datetime(2024, 1, 22, 22, 22, 51),
#   'replyContent': 'Hai kak Ludi, dapat diinformasikan sehubungan dengan adanya perubahan kerja sama hak siar antara MNC Grup dan Vidio, maka dengan berat hati kami harus mengumumkan bahwa Vidio tidak lagi memiliki hak siar atas tayangan MNC Grup. Kamu bisa menyaksikan tayangan seru lainnya di Vidio. Jangan lupa ditambah bintangnya ya kak 😊 -MA\n',
#   'repliedAt': datetime.datetime(2024, 1, 22, 22, 33, 27),
#   'appVersion': '6.20.12-9283f82898'}]

# %%
import pandas as pd
import numpy as np

# Membuat DataFrame dari hasil ulasan
result_df = pd.DataFrame(np.array(result), columns=['review'])

# Memisahkan kolom 'review' menjadi kolom-kolom terpisah
result_df = result_df.join(pd.DataFrame(result_df.pop('review').tolist()))

# mengambil kolom content dan score saja
filtered_df = result_df[['content','score','at']]

# %%
result_df
# Out:
#                                 reviewId               userName  \
# 0   406cb1f2-eb54-4d84-8d68-c5dbb6d5a94e  Kairo & Arafah Videos
# 1   acf0d164-66d1-41f0-b4c0-73464617c4aa         semut ireng777
# 2   daf827ea-f1a8-4379-b91f-ca7dcbc1be9d           Yulian Rizki
# 3   b271e8cf-2f02-4e4d-ba9e-b426778480b7           NAZWA Safira
# 4   5c991071-5a99-4570-aec2-3a75d17bd801              Rama D.K.
# ..                                   ...                    ...
# 95  ae75e3f9-05d6-4b62-9615-c2fdbc204b33           Andika Rafly
# 96  f4cefe0a-ed31-484b-ac9b-27cca0f85f30            Akrom Fariz
# 97  1a073a7c-84ea-41ed-893e-b56b7cb6c9a0          Alpian Alpian
# 98  74302061-02b1-44ae-ad64-4fdedd4e373c              Delia Lia
# 99  5e2eb1df-2741-4319-938e-e0dc6dacbca6          ludi hertanto
#
#                                             userImage  \
# 0   https://play-lh.googleusercontent.com/a-/ALV-U...
# 1   https://play-lh.googleusercontent.com/a-/ALV-U...
# 2   https://play-lh.googleusercontent.com/a-/ALV-U...
# 3   https://play-lh.googleusercontent.com/a-/ALV-U...
# 4   https://play-lh.googleusercontent.com/a-/ALV-U...
# ..                                                ...
# 95  https://play-lh.googleusercontent.com/a-/ALV-U...
# 96  https://play-lh.googleusercontent.com/a-/ALV-U...
# 97  https://play-lh.googleusercontent.com/a/ACg8oc...
# 98  https://play-lh.googleusercontent.com/a/ACg8oc...
# 99  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                               content  score  thumbsUpCount  \
# 0   Sudah aktifkan paket mahal2, tapi masih sering...      3             70
# 1   Masalah iklan yang terlalu sering ternyata men...      1            160
# 2   sangat mantap aplikasi ini tapi setelah update...      1            249
# 3   aslinya aplikasinya udah oke, dari segi film d...      3            480
# 4   Aplikasinya sebenarnya oke karena bisa menonto...      4           1186
# ..                                                ...    ...            ...
# 95  Saya sudah bayar paket platinum mahasiswa via ...      3              6
# 96  Suara jalan gambar enggak, hp redmi noe 10 pro...      1              2
# 97  Manimal iklannya dikurangi lah masa mau nonton...      1              3
# 98  Kenapa ya sekarang aplikasi vidio jadi susah b...      1              6
# 99  Minimal tv nasionalnya dilengkapin dong, mnc g...      1              7
#
#    reviewCreatedVersion                  at  \
# 0    6.24.12-5917139a17 2024-03-07 20:56:47
# 1     6.23.6-ca3febf9df 2024-03-04 15:53:03
# 2     6.23.6-ca3febf9df 2024-02-29 20:36:00
# 3    6.20.12-9283f82898 2024-02-20 19:06:10
# 4    6.21.12-c7a9fd13c6 2024-01-28 00:09:32
# ..                  ...                 ...
# 95   6.21.12-c7a9fd13c6 2024-02-01 19:49:57
# 96   6.20.10-c0def59c2c 2024-01-12 14:30:30
# 97   6.20.12-9283f82898 2024-01-25 20:06:46
# 98   6.21.12-c7a9fd13c6 2024-01-26 15:38:34
# 99   6.20.12-9283f82898 2024-01-22 22:22:51
#
#                                          replyContent           repliedAt  \
# 0   Hai, Kak Kairo. Hindari keluar masuk aplikasi ... 2024-03-07 21:01:50
# 1   Hai kak Semut. Mohon maaf atas ketidaknyamanan... 2024-03-04 16:00:44
# 2   Hai Kak Yulian, mohon maaf untuk ketidaknyaman... 2024-03-02 01:22:37
# 3   Hai Kak Nazwa, terima kasih telah menggunakan ... 2024-02-20 20:25:58
# 4   Hai Kak, terkait kendala tersebut, silakan kir... 2024-01-28 02:20:30
# ..                                                ...                 ...
# 95  Hai kak. kami akan bantu pengecekan untuk kend... 2024-02-01 21:51:40
# 96  Hai Kak Akrom, mohon maaf ketidaknyamanan yang... 2024-01-12 14:34:41
# 97  Hai kak Alpian, ada banyak tayangan yang bisa ... 2024-01-25 21:40:19
# 98  Hai kak Delia, mohon maaf ketidaknyamanan yang... 2024-01-26 15:56:57
# 99  Hai kak Ludi, dapat diinformasikan sehubungan ... 2024-01-22 22:33:27
#
#             appVersion
# 0   6.24.12-5917139a17
# 1    6.23.6-ca3febf9df
# 2    6.23.6-ca3febf9df
# 3   6.20.12-9283f82898
# 4   6.21.12-c7a9fd13c6
# ..                 ...
# 95  6.21.12-c7a9fd13c6
# 96  6.20.10-c0def59c2c
# 97  6.20.12-9283f82898
# 98  6.21.12-c7a9fd13c6
# 99  6.20.12-9283f82898
#
# [100 rows x 11 columns]

# %%
# mengambil kolom content dan score saja
filtered_df = result_df[['content','score','at']]
#sanity check
filtered_df

# %%
from google_play_scraper import app, Sort, reviews
import pandas as pd
import numpy as np

# Fungsi untuk mengambil ulasan dari Google Play
def get_google_play_reviews(app_link, lang='id', country='id', sort_option=Sort.MOST_RELEVANT, reviews_count=100, filter_score=None):
    result, continuation_token = reviews(
        app_link,
        lang=lang,
        country=country,
        sort=sort_option,
        count=reviews_count,
        filter_score_with=filter_score
    )

    # Membuat DataFrame dari hasil ulasan
    result_df = pd.DataFrame(np.array(result), columns=['review'])

    # Memisahkan kolom 'review' menjadi kolom-kolom terpisah
    result_df = result_df.join(pd.DataFrame(result_df.pop('review').tolist()))

    # Mengambil kolom 'content', 'score', dan 'at'
    filtered_df = result_df[['content', 'score', 'at']]

    return filtered_df

# Link aplikasi yang ingin diambil ulasannya
app_link = 'com.vidio.android'

# Pengaturan bahasa dan negara
lang = 'id'
country = 'id'

# Pengaturan untuk mengambil ulasan yang paling relevan
sort_option = Sort.MOST_RELEVANT

# Jumlah ulasan yang ingin diambil
reviews_count = 100

# Filter untuk mengambil semua skor atau rating bintang 1 sampai 5
filter_score = None

# Mengambil ulasan dari Google Play
result_df = get_google_play_reviews(app_link, lang, country, sort_option, reviews_count, filter_score)

# Menampilkan DataFrame hasil ulasan
print(result_df)
# Out:
#                                               content  score  \
# 0   Sudah aktifkan paket mahal2, tapi masih sering...      3
# 1   Masalah iklan yang terlalu sering ternyata men...      1
# 2   sangat mantap aplikasi ini tapi setelah update...      1
# 3   aslinya aplikasinya udah oke, dari segi film d...      3
# 4   Aplikasinya sebenarnya oke karena bisa menonto...      4
# ..                                                ...    ...
# 95  Setelah update, kok ada bug yah, setelah menon...      1
# 96  Saya sudah bayar paket platinum mahasiswa via ...      3
# 97  Suara jalan gambar enggak, hp redmi noe 10 pro...      1
# 98  Manimal iklannya dikurangi lah masa mau nonton...      1
# 99  Kenapa ya sekarang aplikasi vidio jadi susah b...      1
#
#                     at
# 0  2024-03-07 20:56:47
# 1  2024-03-04 15:53:03
# 2  2024-02-29 20:36:00
# 3  2024-02-20 19:06:10
# 4  2024-01-28 00:09:32
# ..                 ...
# 95 2024-01-26 10:27:35
# 96 2024-02-01 19:49:57
# 97 2024-01-12 14:30:30
# 98 2024-01-25 20:06:46
# 99 2024-01-26 15:38:34
#
# [100 rows x 3 columns]

# %%
result_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   content  100 non-null    object
#  1   score    100 non-null    int64
#  2   at       100 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 2.5+ KB

# %%
# Menyimpan DataFrame hasil ulasan ke file CSV
result_df.to_csv("data/1_raw_data/scrape_data.csv", index=False)

# %%
from google_play_scraper import app, Sort, reviews
import pandas as pd
import numpy as np

# Fungsi untuk mengambil ulasan dari Google Play
def get_google_play_reviews(app_link, lang='id', country='id', sort_option=Sort.MOST_RELEVANT, reviews_count=100, filter_score=None):
    result, continuation_token = reviews(
        app_link,
        lang=lang,
        country=country,
        sort=sort_option,
        count=reviews_count,
        filter_score_with=filter_score
    )

    # Membuat DataFrame dari hasil ulasan
    result_df = pd.DataFrame(np.array(result), columns=['review'])

    # Memisahkan kolom 'review' menjadi kolom-kolom terpisah
    result_df = result_df.join(pd.DataFrame(result_df.pop('review').tolist()))

    # Mengambil kolom 'content', 'score', dan 'at'
    filtered_df = result_df[['content', 'score', 'at']]

    return filtered_df

# Fungsi untuk pelabelan sentimen
def labeling(score):
    if score <= 3:  # Ulasan dengan skor di bawah atau sama dengan 3 dianggap negatif
        return 'Negatif'
    elif score == 4:  # Ulasan dengan skor 4 dianggap positif
        return 'Positif'
    elif score == 5:  # Ulasan dengan skor 5 dianggap positif
        return 'Positif'

# Link aplikasi yang ingin diambil ulasannya
app_link = 'com.vidio.android'

# Pengaturan bahasa dan negara
lang = 'id'
country = 'id'

# Pengaturan untuk mengambil ulasan yang paling relevan
sort_option = Sort.MOST_RELEVANT

# Jumlah ulasan yang ingin diambil
reviews_count = 100

# Filter untuk mengambil semua skor atau rating bintang 1 sampai 5
filter_score = None

# Mengambil ulasan dari Google Play
result_df = get_google_play_reviews(app_link, lang, country, sort_option, reviews_count, filter_score)

# Menerapkan fungsi pelabelan pada DataFrame
result_df['sentiment'] = result_df['score'].apply(labeling)

# Menyimpan DataFrame hasil ulasan ke file CSV
result_df.to_csv("data/1_raw_data/scrape_data.csv", index=False)

# Menampilkan DataFrame hasil ulasan
result_df
# Out:
#                                               content  score  \
# 0   Sudah aktifkan paket mahal2, tapi masih sering...      3
# 1   Masalah iklan yang terlalu sering ternyata men...      1
# 2   sangat mantap aplikasi ini tapi setelah update...      1
# 3   aslinya aplikasinya udah oke, dari segi film d...      3
# 4   Aplikasinya sebenarnya oke karena bisa menonto...      4
# ..                                                ...    ...
# 95  Saya sudah bayar paket platinum mahasiswa via ...      3
# 96  Suara jalan gambar enggak, hp redmi noe 10 pro...      1
# 97  Manimal iklannya dikurangi lah masa mau nonton...      1
# 98  Kenapa ya sekarang aplikasi vidio jadi susah b...      1
# 99  Minimal tv nasionalnya dilengkapin dong, mnc g...      1
#
#                     at sentiment
# 0  2024-03-07 20:56:47   Negatif
# 1  2024-03-04 15:53:03   Negatif
# 2  2024-02-29 20:36:00   Negatif
# 3  2024-02-20 19:06:10   Negatif
# 4  2024-01-28 00:09:32   Positif
# ..                 ...       ...
# 95 2024-02-01 19:49:57   Negatif
# 96 2024-01-12 14:30:30   Negatif
# 97 2024-01-25 20:06:46   Negatif
# 98 2024-01-26 15:38:34   Negatif
# 99 2024-01-22 22:22:51   Negatif
#
# [100 rows x 4 columns]

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import re
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
# Fungsi untuk membersihkan teks dengan Sastrawi
def clean_text(text):
    # Mengonversi teks menjadi huruf kecil
    text = text.lower()
    # Menghapus karakter non-alfanumerik
    text = re.sub(r'[^a-z\s]', '', text)
    # Tokenisasi teks
    words = word_tokenize(text)
    # Menghapus stopwords
    stop_words = set(stopwords.words('indonesian'))
    words = [word for word in words if word not in stop_words]
    # Stemming teks dengan Sastrawi
    stemmer = StemmerFactory().create_stemmer()
    words = [stemmer.stem(word) for word in words]
    # Menggabungkan kata-kata menjadi teks bersih
    cleaned_text = ' '.join(words)
    return cleaned_text

# %%
# Membersihkan kolom 'content' pada DataFrame
result_df['cleaned_content'] = result_df['content'].apply(clean_text)

# %%
result_df
# Out:
#                                               content  score  \
# 0   Sudah aktifkan paket mahal2, tapi masih sering...      3
# 1   Masalah iklan yang terlalu sering ternyata men...      1
# 2   sangat mantap aplikasi ini tapi setelah update...      1
# 3   aslinya aplikasinya udah oke, dari segi film d...      3
# 4   Aplikasinya sebenarnya oke karena bisa menonto...      4
# ..                                                ...    ...
# 95  Saya sudah bayar paket platinum mahasiswa via ...      3
# 96  Suara jalan gambar enggak, hp redmi noe 10 pro...      1
# 97  Manimal iklannya dikurangi lah masa mau nonton...      1
# 98  Kenapa ya sekarang aplikasi vidio jadi susah b...      1
# 99  Minimal tv nasionalnya dilengkapin dong, mnc g...      1
#
#                     at sentiment  \
# 0  2024-03-07 20:56:47   Negatif
# 1  2024-03-04 15:53:03   Negatif
# 2  2024-02-29 20:36:00   Negatif
# 3  2024-02-20 19:06:10   Negatif
# 4  2024-01-28 00:09:32   Positif
# ..                 ...       ...
# 95 2024-02-01 19:49:57   Negatif
# 96 2024-01-12 14:30:30   Negatif
# 97 2024-01-25 20:06:46   Negatif
# 98 2024-01-26 15:38:34   Negatif
# 99 2024-01-22 22:22:51   Negatif
#
#                                       cleaned_content
# 0   aktif paket mahal sulit nonton live bola nya g...
# 1   iklan serius langgan premier platinum paket la...
# 2   mantap aplikasi update error kamis feb muncul ...
# 3   asli aplikasi udah oke segi film resolusi vide...
# 4   aplikasi oke tonton mayoritas stasiun televisi...
# ..                                                ...
# 95  bayar paket platinum mahasiswa via dana akses ...
# 96  suara jalan gambar hp redmi noe pro gamungkin ...
# 97  manimal iklan rang nonton siar tv iklan aplika...
# 98  ya aplikasi vidio susah banget bukasuka gak ga...
# 99  minimal tv nasional dilengkapin mnc grup gande...
#
# [100 rows x 5 columns]

# %%
result_df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 result_df.info()
#
# NameError: name 'result_df' is not defined
